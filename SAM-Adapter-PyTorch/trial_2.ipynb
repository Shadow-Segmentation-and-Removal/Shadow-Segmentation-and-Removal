# %%
import os
import matplotlib.pyplot as plt

# Function to plot images side by side
def plot_images(image1_path, image2_path):
    # Load the images
    image1 = plt.imread(image1_path)
    image2 = plt.imread(image2_path)
    
    # Create a figure and axes
    fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    
    # Plot the first image
    axes[0].imshow(image1)
    axes[0].set_title('Shadowed image')
    axes[0].axis('off')
    
    # Plot the second image
    axes[1].imshow(image2)
    axes[1].set_title('Deshadowed Output')
    axes[1].axis('off')
    
    # Show the plot
    plt.show()

# Directory paths containing the images
folder1_path = '/teamspace/studios/this_studio/SAM-Adapter-PyTorch/ISTD_remastered/test_A'
folder2_path = '/teamspace/studios/this_studio/ShadowFormer/results'

# List the files in both folders
folder1_files = os.listdir(folder1_path)
folder2_files = os.listdir(folder2_path)

i=1
# Match the images by name and plot them side by side
for filename in folder1_files:
    if filename in folder2_files:
        print(i)
        if(i == 10):
            break
        image1_path = os.path.join(folder1_path, filename)
        image2_path = os.path.join(folder2_path, filename)
        plot_images(image1_path, image2_path)
        i+=1

# %%
import os
import random
import matplotlib.pyplot as plt

# Function to plot images side by side with filename
def plot_images(image1_path, image2_path, filename):
    # Load the images
    image1 = plt.imread(image1_path)
    image2 = plt.imread(image2_path)
    
    # Create a figure and axes
    fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    
    # Plot the first image
    axes[0].imshow(image1)
    axes[0].set_title('Shadowed image')
    axes[0].axis('off')
    
    # Plot the second image
    axes[1].imshow(image2)
    axes[1].set_title('Deshadowed Output')
    axes[1].axis('off')
    
    # Display the filename
    fig.suptitle(filename, fontsize=12)
    
    # Show the plot
    plt.show()

# Directory paths containing the images
folder1_path = '/teamspace/studios/this_studio/SAM-Adapter-PyTorch/ISTD_Dataset/test/test_B'
folder2_path = '/teamspace/studios/this_studio/SAM-Adapter-PyTorch/ISTD_remastered/test_B'

# List the files in both folders
folder1_files = os.listdir(folder1_path)
folder2_files = os.listdir(folder2_path)

# Randomly select 10 different filenames
random_files = random.sample(folder1_files, 2)

# Plot the randomly selected images
for filename in random_files:
    image1_path = os.path.join(folder1_path, filename)
    image2_path = os.path.join(folder2_path, filename)
    plot_images(image1_path, image2_path, filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 45
#      43 image1_path = os.path.join(folder1_path, filename)
#      44 image2_path = os.path.join(folder2_path, filename)
# ---> 45 plot_images(image1_path, image2_path, filename)
#
# Cell In[2], line 9, in plot_images(image1_path, image2_path, filename)
#       6 def plot_images(image1_path, image2_path, filename):
#       7     # Load the images
#       8     image1 = plt.imread(image1_path)
# ----> 9     image2 = plt.imread(image2_path)
#      11     # Create a figure and axes
#      12     fig, axes = plt.subplots(1, 2, figsize=(10, 5))
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/matplotlib/pyplot.py:2389, in imread(fname, format)
#    2385 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2386 def imread(
#    2387         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2388 ) -> np.ndarray:
# -> 2389     return matplotlib.image.imread(fname, format)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/matplotlib/image.py:1525, in imread(fname, format)
#    1518 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1519     # Pillow doesn't handle URLs directly.
#    1520     raise ValueError(
#    1521         "Please open the URL for reading and pass the "
#    1522         "result to Pillow, e.g. with "
#    1523         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1524         )
# -> 1525 with img_open(fname) as image:
#    1526     return (_pil_png_to_float_array(image)
#    1527             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1528             pil_to_array(image))
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/PIL/ImageFile.py:125, in ImageFile.__init__(self, fp, filename)
#     121 self.decodermaxblock = MAXBLOCK
#     123 if is_path(fp):
#     124     # filename
# --> 125     self.fp = open(fp, "rb")
#     126     self.filename = fp
#     127     self._exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '/teamspace/studios/this_studio/SAM-Adapter-PyTorch/ISTD_remastered/test_B/90-1.png'
